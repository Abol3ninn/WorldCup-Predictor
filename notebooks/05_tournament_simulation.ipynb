# %% [markdown]
# # Let's Predict the Remaining World Cup Matches

# %%
import pandas as pd
import joblib

# %% [markdown]
# ## Load the model

# %%
model = joblib.load("../models/worldcup_predictor.joblib")

# %% [markdown]
# ## Load the datasets

# %%
played_matches = pd.read_csv("../data/processed/played_matches.csv")
played_matches["date"] = pd.to_datetime(played_matches["date"])

future_matches = pd.read_csv("../data/raw/results.csv")
future_matches["date"] = pd.to_datetime(future_matches["date"])

future_matches = future_matches[
    future_matches["home_score"].isna()
]

# %%
future_matches
# Out:
#             date      home_team away_team  home_score  away_score  \
# 49495 2026-07-05         Brazil    Norway         NaN         NaN
# 49496 2026-07-05         Mexico   England         NaN         NaN
# 49497 2026-07-06       Portugal     Spain         NaN         NaN
# 49498 2026-07-06  United States   Belgium         NaN         NaN
# 49499 2026-07-06      Argentina     Egypt         NaN         NaN
# 49500 2026-07-06    Switzerland  Colombia         NaN         NaN
# 49501 2026-07-09         France   Morocco         NaN         NaN
#
#            tournament             city        country  neutral
# 49495  FIFA World Cup  East Rutherford  United States     True
# 49496  FIFA World Cup      Mexico City         Mexico    False
# 49497  FIFA World Cup           Dallas  United States     True
# 49498  FIFA World Cup          Seattle  United States    False
# 49499  FIFA World Cup          Atlanta  United States     True
# ...

# %%
import os
import sys

PROJECT_ROOT = os.path.abspath("..")

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %%
from src.features.build_features import build_features_for_match

# %%
features = build_features_for_match(
    played_matches,
    "Brazil",
    "Norway",
    pd.Timestamp("2026-07-05"),
    True
)

# %%
X_train.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 X_train.columns
#
# NameError: name 'X_train' is not defined

# %%
prediction = model.predict(features)
# Out:
# d:\Documents\Projects\WorldCup-Predictor\.venv\Lib\site-packages\xgboost\data.py:1291: UserWarning: Unknown data type: <class 'NoneType'>, trying to convert it to csr_matrix
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 prediction = model.predict(features)
#
# File d:\Documents\Projects\WorldCup-Predictor\.venv\Lib\site-packages\xgboost\core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File d:\Documents\Projects\WorldCup-Predictor\.venv\Lib\site-packages\xgboost\sklearn.py:1842, in XGBClassifier.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1831 @_deprecate_positional_args
#    1832 def predict(
#    1833     self,
# ...
